# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
(x0,xn)=(0,564)
x=np.linspace(x0,xn,9860)
fx=54*x**5+22*x**4+21*x**3+98*x**2+32+np.cos(x)
ε=0.56*np.random.randn(9860)
y=fx+ε
plt.scatter(x,y)
plt.plot(x,fx)
